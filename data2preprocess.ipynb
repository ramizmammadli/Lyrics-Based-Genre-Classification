# %%
import pandas as pd

# %%
file = pd.read_csv("C:/Users/ramiz/Desktop/test.csv")

# %%
file.head()
# Out:
#                                             wkt_geom  fid   osm_id  \
# 0  MultiLineString ((10413524.18912726454436779 4...    1  4885624
# 1  MultiLineString ((10413524.18912726454436779 4...    2  4885624
# 2  MultiLineString ((10413524.18912726454436779 4...    3  4885624
# 3  MultiLineString ((10413524.18912726454436779 4...    4  4885624
# 4  MultiLineString ((10413524.18912726454436779 4...    5  4885624
#
#              name     type  oneway  distance      angle  \
# 0  Galata Köprüsü  primary       1       460  29.319016
# 1  Galata Köprüsü  primary       1       440  29.319016
# 2  Galata Köprüsü  primary       1       420  29.319016
# 3  Galata Köprüsü  primary       1       400  29.319016
# 4  Galata Köprüsü  primary       1       380  29.319016
#
#                  timestamp
# 0  2022-01-15T20:00:32.000
# 1  2022-01-15T20:00:31.000
# 2  2022-01-15T20:00:30.000
# 3  2022-01-15T20:00:28.000
# 4  2022-01-15T20:00:27.000

# %%
file.dtypes
# Out:
# wkt_geom      object
# fid            int64
# osm_id         int64
# name          object
# type          object
# oneway         int64
# distance       int64
# angle        float64
# timestamp     object
# dtype: object

# %%
lyrics = pd.read_csv('C:/Users/ramiz/Desktop/4th class 1st term/NLP/proje/new_trial/lyrics-data.csv')

# %%
lyrics.head()
# Out:
#              ALink                    SName  \
# 0  /10000-maniacs/           More Than This
# 1  /10000-maniacs/        Because The Night
# 2  /10000-maniacs/           These Are Days
# 3  /10000-maniacs/          A Campfire Song
# 4  /10000-maniacs/  Everyday Is Like Sunday
#
#                                          SLink  \
# 0           /10000-maniacs/more-than-this.html
# 1        /10000-maniacs/because-the-night.html
# 2           /10000-maniacs/these-are-days.html
# 3          /10000-maniacs/a-campfire-song.html
# 4  /10000-maniacs/everyday-is-like-sunday.html
#
#                                                Lyric    Idiom
# 0  I could feel at the time. There was no way of ...  ENGLISH
# 1  Take me now, baby, here as I am. Hold me close...  ENGLISH
# 2  These are. These are days you'll remember. Nev...  ENGLISH
# 3  A lie to say, "O my mountain has coal veins an...  ENGLISH
# 4  Trudging slowly over wet sand. Back to the ben...  ENGLISH

# %%
dataset = lyrics.join(artists.set_index('Link'), on='ALink')

# %%
dataset = dataset.dropna()

# %%
dataset.head()
# Out:
#              ALink              SName                                  SLink  \
# 0  /10000-maniacs/     More Than This     /10000-maniacs/more-than-this.html
# 0  /10000-maniacs/     More Than This     /10000-maniacs/more-than-this.html
# 1  /10000-maniacs/  Because The Night  /10000-maniacs/because-the-night.html
# 1  /10000-maniacs/  Because The Night  /10000-maniacs/because-the-night.html
# 2  /10000-maniacs/     These Are Days     /10000-maniacs/these-are-days.html
#
#                                                Lyric    Idiom         Artist  \
# 0  I could feel at the time. There was no way of ...  ENGLISH  10000 Maniacs
# 0  I could feel at the time. There was no way of ...  ENGLISH  10000 Maniacs
# 1  Take me now, baby, here as I am. Hold me close...  ENGLISH  10000 Maniacs
# 1  Take me now, baby, here as I am. Hold me close...  ENGLISH  10000 Maniacs
# 2  These are. These are days you'll remember. Nev...  ENGLISH  10000 Maniacs
#
# ...

# %%
dataset['Idiom'].value_counts()
# Out:
# ENGLISH           124229
# PORTUGUESE         93110
# SPANISH             4950
# ITALIAN              635
# FRENCH               407
# GERMAN               332
# KINYARWANDA           89
# SWEDISH               27
# FINNISH               24
# ESTONIAN              24
# INDONESIAN            14
# GALICIAN              14
# IRISH                 10
# DANISH                 9
# CROATIAN               9
# HAITIAN_CREOLE         9
# BASQUE                 8
# SUNDANESE              8
# TAGALOG                7
# SWAHILI                7
# NORWEGIAN              7
# CATALAN                5
# NYANJA                 4
# RUSSIAN                4
# CEBUANO                4
# DUTCH                  4
# SERBIAN                4
# MALAY                  3
# SESOTHO                2
# KURDISH                2
# JAPANESE               2
# MALAGASY               2
# TURKISH                2
# ARABIC                 2
# SLOVAK                 1
# CZECH                  1
# SLOVENIAN              1
# ...

# %%
dataset = dataset.loc[dataset['Idiom'] == 'ENGLISH']

# %%
dataset.drop_duplicates(subset=['SName'], inplace=True)

# %%
dataset = dataset.join(dataset['Genres'].str.split(pat=';', expand=True).add_prefix('Genre'))

# %%
dataset.head()
# Out:
#              ALink                    SName  \
# 0  /10000-maniacs/           More Than This
# 1  /10000-maniacs/        Because The Night
# 2  /10000-maniacs/           These Are Days
# 3  /10000-maniacs/          A Campfire Song
# 4  /10000-maniacs/  Everyday Is Like Sunday
#
#                                          SLink  \
# 0           /10000-maniacs/more-than-this.html
# 1        /10000-maniacs/because-the-night.html
# 2           /10000-maniacs/these-are-days.html
# 3          /10000-maniacs/a-campfire-song.html
# 4  /10000-maniacs/everyday-is-like-sunday.html
#
#                                                Lyric    Idiom         Artist  \
# 0  I could feel at the time. There was no way of ...  ENGLISH  10000 Maniacs
# 1  Take me now, baby, here as I am. Hold me close...  ENGLISH  10000 Maniacs
# 2  These are. These are days you'll remember. Nev...  ENGLISH  10000 Maniacs
# 3  A lie to say, "O my mountain has coal veins an...  ENGLISH  10000 Maniacs
# ...

# %%
dataset.head()
# Out:
#              ALink                    SName  \
# 0  /10000-maniacs/           More Than This
# 1  /10000-maniacs/        Because The Night
# 2  /10000-maniacs/           These Are Days
# 3  /10000-maniacs/          A Campfire Song
# 4  /10000-maniacs/  Everyday Is Like Sunday
#
#                                          SLink  \
# 0           /10000-maniacs/more-than-this.html
# 1        /10000-maniacs/because-the-night.html
# 2           /10000-maniacs/these-are-days.html
# 3          /10000-maniacs/a-campfire-song.html
# 4  /10000-maniacs/everyday-is-like-sunday.html
#
#                                                Lyric    Idiom         Artist  \
# 0  I could feel at the time. There was no way of ...  ENGLISH  10000 Maniacs
# 1  Take me now, baby, here as I am. Hold me close...  ENGLISH  10000 Maniacs
# 2  These are. These are days you'll remember. Nev...  ENGLISH  10000 Maniacs
# 3  A lie to say, "O my mountain has coal veins an...  ENGLISH  10000 Maniacs
# ...

# %%
dataset = dataset[dataset['Genre0'].isin(['Rock', 'Pop', 'Hip Hop', 'Indie'])]

# %%
dataset.head()
# Out:
#              ALink                    SName  \
# 0  /10000-maniacs/           More Than This
# 1  /10000-maniacs/        Because The Night
# 2  /10000-maniacs/           These Are Days
# 3  /10000-maniacs/          A Campfire Song
# 4  /10000-maniacs/  Everyday Is Like Sunday
#
#                                          SLink  \
# 0           /10000-maniacs/more-than-this.html
# 1        /10000-maniacs/because-the-night.html
# 2           /10000-maniacs/these-are-days.html
# 3          /10000-maniacs/a-campfire-song.html
# 4  /10000-maniacs/everyday-is-like-sunday.html
#
#                                                Lyric    Idiom         Artist  \
# 0  I could feel at the time. There was no way of ...  ENGLISH  10000 Maniacs
# 1  Take me now, baby, here as I am. Hold me close...  ENGLISH  10000 Maniacs
# 2  These are. These are days you'll remember. Nev...  ENGLISH  10000 Maniacs
# 3  A lie to say, "O my mountain has coal veins an...  ENGLISH  10000 Maniacs
# ...

# %%
dataset.reindex(['Lyric', 'Genre0'], axis=1)
# Out:
#                                                     Lyric Genre0
# 0       I could feel at the time. There was no way of ...   Rock
# 1       Take me now, baby, here as I am. Hold me close...   Rock
# 2       These are. These are days you'll remember. Nev...   Rock
# 3       A lie to say, "O my mountain has coal veins an...   Rock
# 4       Trudging slowly over wet sand. Back to the ben...   Rock
# ...                                                   ...    ...
# 153843  Every avenue in Tokyo. Is saying that I'm gonn...    Pop
# 153848  Only when you're close. Only when you're close...    Pop
# 153859  A dream like this. Not something. You wish for...    Pop
# 153861  Aah, yeah yeah. I see the spotlight in my drea...    Pop
# 153867  Ha, a-plus on the track. Ha, ha, ha, uh, yeah....    Pop
#
# [39878 rows x 2 columns]

# %%
dataset.dropna(inplace=True)

# %%
dataset.to_csv('train2.csv', header=True, index=False)
